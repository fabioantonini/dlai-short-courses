# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"Fou are an expert essay writer. Review the input topic {topic} and provide a draft essay of it using the model {model}" 

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"Reflect on the essay draft {draft} using the input model {model}" 

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"Improves a given essay draft {original_draft} based on feedback from a reflection {reflection}. The revised draft should address the issues mentioned in the feedback. It should improve clarity, coherence, argument strength, and overall flow. The function should use the feedback to guide the revision, and return only the final revised essay." 

    # Get a response from the LLM by creating a chat with the client.
    response = response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Case for Government Regulation of Social Media Platforms
#
# Introduction
#
# In the digital age, social media platforms have become powerful tools for communication, information dissemination, and social interaction. These platforms have undeniably transformed how individuals, organizations, and governments interact. However, with great influence comes significant responsibility, leading to an ongoing debate about whether social media platforms should be regulated by the government. This essay argues that government regulation is necessary to ensure accountability, protect users' rights, and maintain the integrity of information shared on these platforms.
#
# The Impact of Social Media on Society
#
# Social media platforms like Facebook, Twitter, and Instagram play an integral role in shaping public opinion, influencing political landscapes, and altering cultural norms. While they provide space for free expression and community building, they also present challenges such as the spread of misinformation, cyberbullying, and privacy violations. The global reach and instantaneous nature of these platforms mean that misinformation can spread rapidly, impacting elections, public health, and social harmony. Without regulation, these platforms operate with limited oversight, potentially exacerbating societal issues.
#
# The Need for Accountability and Transparency
#
# One of the primary reasons for regulating social media platforms is to ensure accountability and transparency. As private companies, these platforms operate under business models that prioritize user engagement and profit, often at the expense of ethical considerations. Algorithmic biases can lead to echo chambers and the amplification of extreme content. Government regulation can mandate transparency in how decisions are made about content moderation, data usage, and advertising. By holding these companies accountable, governments can prevent abuses of power and ensure that platforms serve the public interest.
#
# Protection of Users' Rights
#
# Social media regulation is also critical for protecting users' rights, particularly concerning privacy and data security. Current practices often involve extensive data collection and surveillance, with users having little understanding or control over how their information is used. Government regulations could establish clear guidelines and standards for data protection, ensuring that users' privacy is respected and that they have rights to their data. Additionally, regulations could protect users from online harassment and hate speech, ensuring that platforms are safe spaces for all individuals.
#
# Preserving Democratic Processes
#
# The influence of social media platforms on democratic processes cannot be understated. From the spread of fake news to targeted political advertising, these platforms have the potential to undermine the integrity of elections and democratic discourse. Government regulation could implement checks and balances to prevent foreign interference and ensure that political content is fair, transparent, and truthful. By upholding democratic values, such regulations would help maintain trust in public institutions and processes.
#
# Conclusion
#
# In conclusion, while social media platforms have revolutionized communication and connectivity, the need for government regulation is evident. Such regulation would provide accountability and transparency, protect users' rights, and preserve democratic processes. By implementing thoughtful and balanced regulations, governments can harness the positive potential of social media while mitigating its risks. As digital landscapes continue to evolve, it is crucial that societies strike the right balance between innovation and regulation, ensuring that social media contributes positively to the global discourse.
#
# 🧠 Feedback:
#
# Here’s a structured reflection on your draft, covering what’s working well and where you might deepen or tighten the argument:
#
# 1. Introduction and Thesis
# • Strengths: You open with clear context (“digital age,” “powerful tools”) and state your thesis—that regulation is necessary to ensure accountability, protect rights, and safeguard information integrity.
# • Suggestions: You could grab the reader from the first sentence with a compelling fact or anecdote (e.g., a high-profile data breach or viral misinformation incident). That will ground the abstract thesis in a concrete event.
#
# 2. Organization and Flow
# • Strengths: You use a classic problem–solution structure: you describe the problems (misinformation, privacy, democratic risk) and then propose regulation. Each section has a clear purpose.
# • Suggestions: Consider whether your headings fully mirror your central claims. For instance, “The Impact of Social Media on Society” might be retitled “The Social Costs of Unregulated Platforms” to foreground the urgency you want readers to feel.
#
# 3. Use of Evidence
# • Strengths: You correctly identify key issues—algorithmic bias, data harvesting, election interference.
# • Suggestions: Right now your claims are general. Bolster them with statistics, case studies, or legal precedents. For example:
#   – Cite a study on how quickly a piece of election-related misinformation can reach X million users.
#   – Mention the Cambridge Analytica scandal or the EU’s GDPR fines as real-world evidence of harms and existing regulatory frameworks.
#
# 4. Nuance and Counterarguments
# • Strengths: You focus on positive goals: transparency, user protection, democratic integrity.
# • Suggestions: Preempt objections about government overreach or censorship. You might briefly acknowledge free-speech concerns and then explain how smart regulation can include strong due-process protections or independent oversight bodies to balance competing interests.
#
# 5. Legal and Technical Details
# • Strengths: You call for “mandated transparency” and “clear guidelines.”
# • Suggestions: Give your reader a sense of what that looks like in practice. For instance, should platforms be required to:
#   – Publish quarterly transparency reports on content removals?
#   – Allow third-party audits of their recommendation algorithms?
#   – Obtain express user consent before sharing data with advertisers?
# Concrete proposals will make your argument more persuasive.
#
# 6. Tone and Style
# • Strengths: Your writing is clear, formal, and free of jargon.
# • Suggestions: Vary sentence structure to keep the prose engaging. Where you have long, compound sentences, try splitting them or adding a brief illustrative example.
#
# 7. Conclusion
# • Strengths: You restate the stakes—innovation vs. regulation—and call for balance.
# • Suggestions: End on a more vivid note. Perhaps sketch a vision of a healthier information ecosystem or cite a country or locality that’s already piloting the kind of regulation you advocate.
#
# Final Thoughts
# Overall, you have the bones of a solid policy essay: a clear problem, logically ordered solutions, and a call to action. To turn it into a truly compelling piece, ground your claims in specifics (data, examples, existing laws), acknowledge and defuse counterarguments, and give readers a sharper picture of what “responsible regulation” looks like on the ground. That added depth will strengthen both your ethos (authority) and pathos (emotional impact) and leave readers eager to support your proposal.
#
# ✍️ Revised:
#
# **Title: The Urgent Case for Government Regulation of Social Media Platforms**
#
# **Introduction**
#
# Imagine a world where a single misleading tweet can disrupt elections or where personal data is traded as casually as goods in a marketplace. This is not a hypothetical scenario, but a reality in our digital age. Social media platforms such as Facebook, Twitter, and Instagram have revolutionized communication and information exchange, yet this revolution brings with it the potential for immense social disruption. This essay contends that government regulation is essential to enforce accountability, guard users' rights, and ensure the integrity of information shared on these platforms.
#
# **The Social Costs of Unregulated Platforms**
#
# Social media platforms hold significant sway over public discourse, shaping opinions and influencing cultural norms. They offer a platform for free expression, yet this freedom can lead to the propagation of misinformation, cyberbullying, and privacy breaches. For instance, studies indicate that false news stories are 70% more likely to be retweeted than true ones, with damaging implications for elections and public health. Left unchecked, these platforms exacerbate societal issues, highlighting the need for government oversight.
#
# **Ensuring Accountability and Transparency**
#
# The call for regulation is fundamentally about ensuring accountability and transparency. Social media companies primarily operate on business models that focus on maximizing engagement and profits, sometimes at the cost of ethical standards. Issues like algorithmic biases lead to echo chambers and exacerbate the spread of extreme content. Regulation would mandate transparency in decision-making processes related to content moderation, data usage, and advertising. By requiring platforms to publish quarterly transparency reports or allowing third-party audits, regulation can ensure these companies serve the public interest rather than their own.
#
# **Safeguarding Users' Rights**
#
# Protecting users' rights, particularly privacy and data security, is another core argument for regulation. Most users are unaware of the extent of data collection happening behind the screens. Current practices often involve extensive surveillance, with little user control over data usage. Implementing regulations similar to the EU's General Data Protection Regulation (GDPR) could enforce clear guidelines for data protection, granting users more control and visibility over their data. Moreover, regulations could mandate rigorous procedures to counteract online harassment and hate speech, fostering safer online environments.
#
# **Preserving Democratic Processes**
#
# Social media's influence on democratic processes cannot be understated. Platforms that spread fake news or allow unchecked political advertising have the potential to erode the integrity of elections. Regulatory measures could include obligatory disclosures of political ad sponsors and stricter rules to curb foreign interference. By ensuring political content is fair and transparent, regulations would fortify democratic values and restore trust in public institutions.
#
# **Addressing Concerns of Overreach**
#
# While some may argue that government regulation risks overreach or censorship, it's crucial to strike a balance. Regulations can incorporate strong due-process protections and establish independent oversight bodies to guard against potential government biases. This approach ensures that regulation upholds free speech while safeguarding against the platforms' worst excesses.
#
# **Conclusion**
#
# In conclusion, the unregulated might of social media platforms presents significant risks that necessitate government intervention. Accountability, user protection, and the preservation of democratic structures are compelling reasons for thoughtful regulation. Countries such as Germany, with its NetzDG law, have demonstrated that balanced regulation is feasible and effective. As the digital landscape continues to evolve, it is our collective responsibility to implement frameworks that harness the benefits of social media while mitigating its risks. By envisioning a regulatory framework that champions transparency, fairness, and data privacy, societies can create a healthier information ecosystem and ensure that social media plays a constructive role in global discourse.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Case for Government Regulation of Social Media Platforms
#
# Introduction
#
# In the digital age, social media platforms have become powerful tools for communication, information dissemination, and social interaction. These platforms have undeniably transformed how individuals, organizations, and governments interact. However, with great influence comes significant responsibility, leading to an ongoing debate about whether social media platforms should be regulated by the government. This essay argues that government regulation is necessary to ensure accountability, protect users' rights, and maintain the integrity of information shared on these platforms.
#
# The Impact of Social Media on Society
#
# Social media platforms like Facebook, Twitter, and Instagram play an integral role in shaping public opinion, influencing political landscapes, and altering cultural norms. While they provide space for free expression and community building, they also present challenges such as the spread of misinformation, cyberbullying, and privacy violations. The global reach and instantaneous nature of these platforms mean that misinformation can spread rapidly, impacting elections, public health, and social harmony. Without regulation, these platforms operate with limited oversight, potentially exacerbating societal issues.
#
# The Need for Accountability and Transparency
#
# One of the primary reasons for regulating social media platforms is to ensure accountability and transparency. As private companies, these platforms operate under business models that prioritize user engagement and profit, often at the expense of ethical considerations. Algorithmic biases can lead to echo chambers and the amplification of extreme content. Government regulation can mandate transparency in how decisions are made about content moderation, data usage, and advertising. By holding these companies accountable, governments can prevent abuses of power and ensure that platforms serve the public interest.
#
# Protection of Users' Rights
#
# Social media regulation is also critical for protecting users' rights, particularly concerning privacy and data security. Current practices often involve extensive data collection and surveillance, with users having little understanding or control over how their information is used. Government regulations could establish clear guidelines and standards for data protection, ensuring that users' privacy is respected and that they have rights to their data. Additionally, regulations could protect users from online harassment and hate speech, ensuring that platforms are safe spaces for all individuals.
#
# Preserving Democratic Processes
#
# The influence of social media platforms on democratic processes cannot be understated. From the spread of fake news to targeted political advertising, these platforms have the potential to undermine the integrity of elections and democratic discourse. Government regulation could implement checks and balances to prevent foreign interference and ensure that political content is fair, transparent, and truthful. By upholding democratic values, such regulations would help maintain trust in public institutions and processes.
#
# Conclusion
#
# In conclusion, while social media platforms have revolutionized communication and connectivity, the need for government regulation is evident. Such regulation would provide accountability and transparency, protect users' rights, and preserve democratic processes. By implementing thoughtful and balanced regulations, governments can harness the positive potential of social media while mitigating its risks. As digital landscapes continue to evolve, it is crucial that societies strike the right balance between innovation and regulation, ensuring that social media contributes positively to the global discourse.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Here’s a structured reflection on your draft, covering what’s working well and where you might deepen or tighten the argument:
#
# 1. Introduction and Thesis
# • Strengths: You open with clear context (“digital age,” “powerful tools”) and state your thesis—that regulation is necessary to ensure accountability, protect rights, and safeguard information integrity.
# • Suggestions: You could grab the reader from the first sentence with a compelling fact or anecdote (e.g., a high-profile data breach or viral misinformation incident). That will ground the abstract thesis in a concrete event.
#
# 2. Organization and Flow
# • Strengths: You use a classic problem–solution structure: you describe the problems (misinformation, privacy, democratic risk) and then propose regulation. Each section has a clear purpose.
# • Suggestions: Consider whether your headings fully mirror your central claims. For instance, “The Impact of Social Media on Society” might be retitled “The Social Costs of Unregulated Platforms” to foreground the urgency you want readers to feel.
#
# 3. Use of Evidence
# • Strengths: You correctly identify key issues—algorithmic bias, data harvesting, election interference.
# • Suggestions: Right now your claims are general. Bolster them with statistics, case studies, or legal precedents. For example:
#   – Cite a study on how quickly a piece of election-related misinformation can reach X million users.
#   – Mention the Cambridge Analytica scandal or the EU’s GDPR fines as real-world evidence of harms and existing regulatory frameworks.
#
# 4. Nuance and Counterarguments
# • Strengths: You focus on positive goals: transparency, user protection, democratic integrity.
# • Suggestions: Preempt objections about government overreach or censorship. You might briefly acknowledge free-speech concerns and then explain how smart regulation can include strong due-process protections or independent oversight bodies to balance competing interests.
#
# 5. Legal and Technical Details
# • Strengths: You call for “mandated transparency” and “clear guidelines.”
# • Suggestions: Give your reader a sense of what that looks like in practice. For instance, should platforms be required to:
#   – Publish quarterly transparency reports on content removals?
#   – Allow third-party audits of their recommendation algorithms?
#   – Obtain express user consent before sharing data with advertisers?
# Concrete proposals will make your argument more persuasive.
#
# 6. Tone and Style
# • Strengths: Your writing is clear, formal, and free of jargon.
# • Suggestions: Vary sentence structure to keep the prose engaging. Where you have long, compound sentences, try splitting them or adding a brief illustrative example.
#
# 7. Conclusion
# • Strengths: You restate the stakes—innovation vs. regulation—and call for balance.
# • Suggestions: End on a more vivid note. Perhaps sketch a vision of a healthier information ecosystem or cite a country or locality that’s already piloting the kind of regulation you advocate.
#
# Final Thoughts
# Overall, you have the bones of a solid policy essay: a clear problem, logically ordered solutions, and a call to action. To turn it into a truly compelling piece, ground your claims in specifics (data, examples, existing laws), acknowledge and defuse counterarguments, and give readers a sharper picture of what “responsible regulation” looks like on the ground. That added depth will strengthen both your ethos (authority) and pathos (emotional impact) and leave readers eager to support your proposal.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">**Title: The Urgent Case for Government Regulation of Social Media Platforms**
#
# **Introduction**
#
# Imagine a world where a single misleading tweet can disrupt elections or where personal data is traded as casually as goods in a marketplace. This is not a hypothetical scenario, but a reality in our digital age. Social media platforms such as Facebook, Twitter, and Instagram have revolutionized communication and information exchange, yet this revolution brings with it the potential for immense social disruption. This essay contends that government regulation is essential to enforce accountability, guard users' rights, and ensure the integrity of information shared on these platforms.
#
# **The Social Costs of Unregulated Platforms**
#
# Social media platforms hold significant sway over public discourse, shaping opinions and influencing cultural norms. They offer a platform for free expression, yet this freedom can lead to the propagation of misinformation, cyberbullying, and privacy breaches. For instance, studies indicate that false news stories are 70% more likely to be retweeted than true ones, with damaging implications for elections and public health. Left unchecked, these platforms exacerbate societal issues, highlighting the need for government oversight.
#
# **Ensuring Accountability and Transparency**
#
# The call for regulation is fundamentally about ensuring accountability and transparency. Social media companies primarily operate on business models that focus on maximizing engagement and profits, sometimes at the cost of ethical standards. Issues like algorithmic biases lead to echo chambers and exacerbate the spread of extreme content. Regulation would mandate transparency in decision-making processes related to content moderation, data usage, and advertising. By requiring platforms to publish quarterly transparency reports or allowing third-party audits, regulation can ensure these companies serve the public interest rather than their own.
#
# **Safeguarding Users' Rights**
#
# Protecting users' rights, particularly privacy and data security, is another core argument for regulation. Most users are unaware of the extent of data collection happening behind the screens. Current practices often involve extensive surveillance, with little user control over data usage. Implementing regulations similar to the EU's General Data Protection Regulation (GDPR) could enforce clear guidelines for data protection, granting users more control and visibility over their data. Moreover, regulations could mandate rigorous procedures to counteract online harassment and hate speech, fostering safer online environments.
#
# **Preserving Democratic Processes**
#
# Social media's influence on democratic processes cannot be understated. Platforms that spread fake news or allow unchecked political advertising have the potential to erode the integrity of elections. Regulatory measures could include obligatory disclosures of political ad sponsors and stricter rules to curb foreign interference. By ensuring political content is fair and transparent, regulations would fortify democratic values and restore trust in public institutions.
#
# **Addressing Concerns of Overreach**
#
# While some may argue that government regulation risks overreach or censorship, it's crucial to strike a balance. Regulations can incorporate strong due-process protections and establish independent oversight bodies to guard against potential government biases. This approach ensures that regulation upholds free speech while safeguarding against the platforms' worst excesses.
#
# **Conclusion**
#
# In conclusion, the unregulated might of social media platforms presents significant risks that necessitate government intervention. Accountability, user protection, and the preservation of democratic structures are compelling reasons for thoughtful regulation. Countries such as Germany, with its NetzDG law, have demonstrated that balanced regulation is feasible and effective. As the digital landscape continues to evolve, it is our collective responsibility to implement frameworks that harness the benefits of social media while mitigating its risks. By envisioning a regulatory framework that champions transparency, fairness, and data privacy, societies can create a healthier information ecosystem and ensure that social media plays a constructive role in global discourse.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
