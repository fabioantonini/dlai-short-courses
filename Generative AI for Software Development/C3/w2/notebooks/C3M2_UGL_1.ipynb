# %% [markdown]
# # Ungraded Lab - Lecture Implementing CRUD operations
#
# This ungraded lab has the content discussed in the lecture Implementing CRUD operations, your task is to implement the CRUD operations for the tables Product, Order and OrderItem.

# %%
from sqlalchemy import create_engine, Column, Integer, String, ForeignKey
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker, relationship
import pickle

Base = declarative_base()

class User(Base):
    __tablename__ = 'users'
    id = Column(Integer, primary_key=True)
    name = Column(String)
    email = Column(String, unique=True)
    orders = relationship("Order", back_populates="user")

class Product(Base):
    __tablename__ = 'products'
    id = Column(Integer, primary_key=True)
    name = Column(String)
    price = Column(Integer)
    order_items = relationship("OrderItem", back_populates="product")

class Order(Base):
    __tablename__ = 'orders'
    id = Column(Integer, primary_key=True)
    user_id = Column(Integer, ForeignKey('users.id'))
    user = relationship("User", back_populates="orders")
    order_items = relationship("OrderItem", back_populates="order")

class OrderItem(Base):
    __tablename__ = 'order_items'
    id = Column(Integer, primary_key=True)
    order_id = Column(Integer, ForeignKey('orders.id'))
    product_id = Column(Integer, ForeignKey('products.id'))
    quantity = Column(Integer)
    order = relationship("Order", back_populates="order_items")
    product = relationship("Product", back_populates="order_items")

engine = create_engine('sqlite:///ecommerce.db', echo=True)
Base.metadata.create_all(engine)

Session = sessionmaker(bind=engine)
session = Session()


## USER TABLE CRUD
# Create
def add_user(name, email):
    new_user = User(name=name, email=email)
    session.add(new_user)
    session.commit()

# Read
def get_user(user_id):
    return session.query(User).filter(User.id == user_id).first()

# Update
def update_user(user_id, name=None, email=None):
    user = session.query(User).filter(User.id == user_id).first()
    if user:
        if name:
            user.name = name
        if email:
            user.email = email
        session.commit()

# Delete
def delete_user(user_id):
    user = session.query(User).filter(User.id == user_id).first()
    if user:
        session.delete(user)
        session.commit()
# Out:
# 2024-12-22 11:36:25,604 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:36:25,605 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("users")
# 2024-12-22 11:36:25,605 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-12-22 11:36:25,641 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("users")
# 2024-12-22 11:36:25,641 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-12-22 11:36:25,642 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("products")
# 2024-12-22 11:36:25,642 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-12-22 11:36:25,658 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("products")
# 2024-12-22 11:36:25,658 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-12-22 11:36:25,659 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("orders")
# 2024-12-22 11:36:25,659 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-12-22 11:36:25,676 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("orders")
# 2024-12-22 11:36:25,676 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-12-22 11:36:25,677 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("order_items")
# 2024-12-22 11:36:25,677 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-12-22 11:36:25,696 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("order_items")
# 2024-12-22 11:36:25,696 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-12-22 11:36:25,697 INFO sqlalchemy.engine.Engine
# CREATE TABLE users (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	email VARCHAR,
# 	PRIMARY KEY (id),
# 	UNIQUE (email)
# )
#
#
# 2024-12-22 11:36:25,697 INFO sqlalchemy.engine.Engine [no key 0.00034s] ()
# 2024-12-22 11:36:25,756 INFO sqlalchemy.engine.Engine
# CREATE TABLE products (
# 	id INTEGER NOT NULL,
# 	name VARCHAR,
# 	price INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2024-12-22 11:36:25,757 INFO sqlalchemy.engine.Engine [no key 0.00041s] ()
# /tmp/ipykernel_90/95043806.py:6: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()
# 2024-12-22 11:36:25,832 INFO sqlalchemy.engine.Engine
# CREATE TABLE orders (
# 	id INTEGER NOT NULL,
# 	user_id INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(user_id) REFERENCES users (id)
# )
#
#
# 2024-12-22 11:36:25,833 INFO sqlalchemy.engine.Engine [no key 0.00039s] ()
# 2024-12-22 11:36:25,910 INFO sqlalchemy.engine.Engine
# CREATE TABLE order_items (
# 	id INTEGER NOT NULL,
# 	order_id INTEGER,
# 	product_id INTEGER,
# 	quantity INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(order_id) REFERENCES orders (id),
# 	FOREIGN KEY(product_id) REFERENCES products (id)
# )
#
#
# 2024-12-22 11:36:25,910 INFO sqlalchemy.engine.Engine [no key 0.00037s] ()
# 2024-12-22 11:36:25,979 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Exercise 1
#
# Using an LLM, implement the CRUD operations in the Product table.

# %%
## PRODUCT TABLE CRUD
## PRODUCT TABLE CRUD

# Create
def add_product(name, price):
    new_product = Product(name=name, price=price)
    session.add(new_product)
    session.commit()

# Read
def get_product(product_id):
    return session.query(Product).filter(Product.id == product_id).first()

# Update
def update_product(product_id, name=None, price=None):
    product = session.query(Product).filter(Product.id == product_id).first()
    if product:
        if name:
            product.name = name
        if price is not None:  # Check for None to allow setting price to 0
            product.price = price
        session.commit()

# Delete
def delete_product(product_id):
    product = session.query(Product).filter(Product.id == product_id).first()
    if product:
        session.delete(product)
        session.commit()

# %% [markdown]
# ### Exercise 2
#
# Using an LLM, implement the CRUD operations in the Order table.

# %%
## ORDERS TABLE CRUD
## ORDER TABLE CRUD

# Create
def add_order(user_id):
    new_order = Order(user_id=user_id)
    session.add(new_order)
    session.commit()

# Read
def get_order(order_id):
    return session.query(Order).filter(Order.id == order_id).first()

# Update
def update_order(order_id, user_id=None):
    order = session.query(Order).filter(Order.id == order_id).first()
    if order:
        if user_id is not None:  # Check for None to allow setting a new user ID
            order.user_id = user_id
        session.commit()

# Delete
def delete_order(order_id):
    order = session.query(Order).filter(Order.id == order_id).first()
    if order:
        session.delete(order)
        session.commit()

# %% [markdown]
# ### Exercise 3
#
# Using an LLM, implement the CRUD operations in the OrderItem table.

# %%
## ORDERITEM TABLE CRUD
# Create
def add_order_item(order_id, product_id, quantity):
    new_order_item = OrderItem(order_id=order_id, product_id=product_id, quantity=quantity)
    session.add(new_order_item)
    session.commit()

# Read
def get_order_item(order_item_id):
    return session.query(OrderItem).filter(OrderItem.id == order_item_id).first()

# Update
def update_order_item(order_item_id, order_id=None, product_id=None, quantity=None):
    order_item = session.query(OrderItem).filter(OrderItem.id == order_item_id).first()
    if order_item:
        if order_id is not None:
            order_item.order_id = order_id
        if product_id is not None:
            order_item.product_id = product_id
        if quantity is not None:
            order_item.quantity = quantity
        session.commit()

# Delete
def delete_order_item(order_item_id):
    order_item = session.query(OrderItem).filter(OrderItem.id == order_item_id).first()
    if order_item:
        session.delete(order_item)
        session.commit()

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Exercise 1

# %%
## PRODUCT TABLE CRUD
# Create
def add_product(name, price):
    new_product = Product(name=name, price=price)
    session.add(new_product)
    session.commit()

# Read
def get_product(product_id):
    return session.query(Product).filter(Product.id == product_id).first()

# Update
def update_product(product_id, name=None, price=None):
    product = session.query(Product).filter(Product.id == product_id).first()
    if product:
        if name:
            product.name = name
        if price:
            product.price = price
        session.commit()

# Delete
def delete_product(product_id):
    product = session.query(Product).filter(Product.id == product_id).first()
    if product:
        session.delete(product)
        session.commit()

# %% [markdown]
# ## Exercise 2

# %%
## ORDERS TABLE CRUD
# Create
def add_order(user_id):
    new_order = Order(user_id=user_id)
    session.add(new_order)
    session.commit()

# Read
def get_order(order_id):
    return session.query(Order).filter(Order.id == order_id).first()

# Update
def update_order(order_id, user_id=None):
    order = session.query(Order).filter(Order.id == order_id).first()
    if order:
        if user_id:
            order.user_id = user_id
        session.commit()

# Delete
def delete_order(order_id):
    order = session.query(Order).filter(Order.id == order_id).first()
    if order:
        session.delete(order)
        session.commit()

# %% [markdown]
# ### Exercise 3

# %%
## ORDER ITEMS CRUD
# Create
def add_order_item(order_id, product_id, quantity):
    new_order_item = OrderItem(order_id=order_id, product_id=product_id, quantity=quantity)
    session.add(new_order_item)
    session.commit()

# Read
def get_order_item(order_item_id):
    return session.query(OrderItem).filter(OrderItem.id == order_item_id).first()

# Update
def update_order_item(order_item_id, order_id=None, product_id=None, quantity=None):
    order_item = session.query(OrderItem).filter(OrderItem.id == order_item_id).first()
    if order_item:
        if order_id:
            order_item.order_id = order_id
        if product_id:
            order_item.product_id = product_id
        if quantity:
            order_item.quantity = quantity
        session.commit()

# Delete
def delete_order_item(order_item_id):
    order_item = session.query(OrderItem).filter(OrderItem.id == order_item_id).first()
    if order_item:
        session.delete(order_item)
        session.commit()

# %%
def add_sample_data():
    # Adding users
    user_data = [
        ("Alice", "alice@example.com"),
        ("Bob", "bob@example.com"),
        ("Charlie", "charlie@example.com"),
        ("David", "david@example.com"),
        ("Eve", "eve@example.com"),
        ("Frank", "frank@example.com"),
        ("Grace", "grace@example.com"),
        ("Heidi", "heidi@example.com"),
        ("Ivan", "ivan@example.com"),
        ("Judy", "judy@example.com")
    ]
    for name, email in user_data:
        add_user(name, email)

    # Adding products
    product_data = [
        ("Laptop", 1000),
        ("Smartphone", 500),
        ("Tablet", 300),
        ("Monitor", 150),
        ("Keyboard", 50),
        ("Mouse", 25),
        ("Printer", 200),
        ("Router", 75),
        ("Webcam", 60),
        ("Headphones", 80)
    ]
    for name, price in product_data:
        add_product(name, price)

    # Adding orders
    for i in range(1, 11):
        add_order(i)

    # Adding order_items
    order_item_data = [
        (1, 1, 2),
        (1, 2, 1),
        (2, 3, 1),
        (2, 4, 2),
        (3, 5, 3),
        (3, 6, 1),
        (4, 7, 2),
        (4, 8, 1),
        (5, 9, 1),
        (5, 10, 2),
        (6, 1, 1),
        (6, 2, 2),
        (7, 3, 1),
        (7, 4, 1),
        (8, 5, 2),
        (8, 6, 1),
        (9, 7, 3),
        (9, 8, 1),
        (10, 9, 1),
        (10, 10, 1)
    ]
    for order_id, product_id, quantity in order_item_data:
        add_order_item(order_id, product_id, quantity)

# %%
add_sample_data()
# Out:
# 2024-12-22 11:38:43,072 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:43,074 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2024-12-22 11:38:43,074 INFO sqlalchemy.engine.Engine [generated in 0.00058s] ('Alice', 'alice@example.com')
# 2024-12-22 11:38:43,104 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:43,156 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:43,157 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2024-12-22 11:38:43,157 INFO sqlalchemy.engine.Engine [cached since 0.08337s ago] ('Bob', 'bob@example.com')
# 2024-12-22 11:38:43,186 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:43,236 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:43,237 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2024-12-22 11:38:43,237 INFO sqlalchemy.engine.Engine [cached since 0.1632s ago] ('Charlie', 'charlie@example.com')
# 2024-12-22 11:38:43,261 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:43,312 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:43,313 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2024-12-22 11:38:43,313 INFO sqlalchemy.engine.Engine [cached since 0.2391s ago] ('David', 'david@example.com')
# 2024-12-22 11:38:43,348 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:43,405 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:43,406 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2024-12-22 11:38:43,406 INFO sqlalchemy.engine.Engine [cached since 0.3326s ago] ('Eve', 'eve@example.com')
# 2024-12-22 11:38:43,434 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:43,486 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:43,486 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2024-12-22 11:38:43,487 INFO sqlalchemy.engine.Engine [cached since 0.4131s ago] ('Frank', 'frank@example.com')
# 2024-12-22 11:38:43,513 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:43,563 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:43,564 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2024-12-22 11:38:43,564 INFO sqlalchemy.engine.Engine [cached since 0.4902s ago] ('Grace', 'grace@example.com')
# 2024-12-22 11:38:43,590 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:43,637 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:43,638 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2024-12-22 11:38:43,638 INFO sqlalchemy.engine.Engine [cached since 0.5643s ago] ('Heidi', 'heidi@example.com')
# 2024-12-22 11:38:43,666 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:43,711 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:43,712 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2024-12-22 11:38:43,712 INFO sqlalchemy.engine.Engine [cached since 0.6384s ago] ('Ivan', 'ivan@example.com')
# 2024-12-22 11:38:43,737 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:43,783 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:43,783 INFO sqlalchemy.engine.Engine INSERT INTO users (name, email) VALUES (?, ?)
# 2024-12-22 11:38:43,784 INFO sqlalchemy.engine.Engine [cached since 0.7099s ago] ('Judy', 'judy@example.com')
# 2024-12-22 11:38:43,810 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:43,854 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:43,855 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2024-12-22 11:38:43,856 INFO sqlalchemy.engine.Engine [generated in 0.00047s] ('Laptop', 1000)
# 2024-12-22 11:38:43,879 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:43,925 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:43,925 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2024-12-22 11:38:43,926 INFO sqlalchemy.engine.Engine [cached since 0.07062s ago] ('Smartphone', 500)
# 2024-12-22 11:38:43,951 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,000 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,000 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2024-12-22 11:38:44,001 INFO sqlalchemy.engine.Engine [cached since 0.1454s ago] ('Tablet', 300)
# 2024-12-22 11:38:44,026 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,075 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,075 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2024-12-22 11:38:44,076 INFO sqlalchemy.engine.Engine [cached since 0.2205s ago] ('Monitor', 150)
# 2024-12-22 11:38:44,102 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,145 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,146 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2024-12-22 11:38:44,146 INFO sqlalchemy.engine.Engine [cached since 0.2907s ago] ('Keyboard', 50)
# 2024-12-22 11:38:44,171 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,219 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,220 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2024-12-22 11:38:44,220 INFO sqlalchemy.engine.Engine [cached since 0.3646s ago] ('Mouse', 25)
# 2024-12-22 11:38:44,246 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,291 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,292 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2024-12-22 11:38:44,292 INFO sqlalchemy.engine.Engine [cached since 0.4371s ago] ('Printer', 200)
# 2024-12-22 11:38:44,318 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,366 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,367 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2024-12-22 11:38:44,367 INFO sqlalchemy.engine.Engine [cached since 0.5122s ago] ('Router', 75)
# 2024-12-22 11:38:44,394 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,443 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,444 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2024-12-22 11:38:44,444 INFO sqlalchemy.engine.Engine [cached since 0.5889s ago] ('Webcam', 60)
# 2024-12-22 11:38:44,469 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,514 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,515 INFO sqlalchemy.engine.Engine INSERT INTO products (name, price) VALUES (?, ?)
# 2024-12-22 11:38:44,515 INFO sqlalchemy.engine.Engine [cached since 0.66s ago] ('Headphones', 80)
# 2024-12-22 11:38:44,540 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,591 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,592 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2024-12-22 11:38:44,592 INFO sqlalchemy.engine.Engine [generated in 0.00046s] (1,)
# 2024-12-22 11:38:44,618 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,665 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,666 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2024-12-22 11:38:44,666 INFO sqlalchemy.engine.Engine [cached since 0.07443s ago] (2,)
# 2024-12-22 11:38:44,693 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,739 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,740 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2024-12-22 11:38:44,740 INFO sqlalchemy.engine.Engine [cached since 0.1486s ago] (3,)
# 2024-12-22 11:38:44,764 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,815 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,816 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2024-12-22 11:38:44,816 INFO sqlalchemy.engine.Engine [cached since 0.2247s ago] (4,)
# 2024-12-22 11:38:44,844 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,891 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,892 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2024-12-22 11:38:44,892 INFO sqlalchemy.engine.Engine [cached since 0.3004s ago] (5,)
# 2024-12-22 11:38:44,915 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:44,963 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:44,964 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2024-12-22 11:38:44,964 INFO sqlalchemy.engine.Engine [cached since 0.3724s ago] (6,)
# 2024-12-22 11:38:44,991 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,036 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,037 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2024-12-22 11:38:45,038 INFO sqlalchemy.engine.Engine [cached since 0.4464s ago] (7,)
# 2024-12-22 11:38:45,066 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,111 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,112 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2024-12-22 11:38:45,113 INFO sqlalchemy.engine.Engine [cached since 0.5212s ago] (8,)
# 2024-12-22 11:38:45,138 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,188 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,189 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2024-12-22 11:38:45,190 INFO sqlalchemy.engine.Engine [cached since 0.5983s ago] (9,)
# 2024-12-22 11:38:45,219 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,265 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,271 INFO sqlalchemy.engine.Engine INSERT INTO orders (user_id) VALUES (?)
# 2024-12-22 11:38:45,271 INFO sqlalchemy.engine.Engine [cached since 0.6796s ago] (10,)
# 2024-12-22 11:38:45,300 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,347 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,371 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:45,372 INFO sqlalchemy.engine.Engine [generated in 0.00076s] (1, 1, 2)
# 2024-12-22 11:38:45,399 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,446 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,447 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:45,447 INFO sqlalchemy.engine.Engine [cached since 0.07642s ago] (1, 2, 1)
# 2024-12-22 11:38:45,471 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,517 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,518 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:45,518 INFO sqlalchemy.engine.Engine [cached since 0.1473s ago] (2, 3, 1)
# 2024-12-22 11:38:45,542 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,605 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,606 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:45,606 INFO sqlalchemy.engine.Engine [cached since 0.2355s ago] (2, 4, 2)
# 2024-12-22 11:38:45,632 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,681 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,682 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:45,682 INFO sqlalchemy.engine.Engine [cached since 0.3111s ago] (3, 5, 3)
# 2024-12-22 11:38:45,707 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,752 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,752 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:45,753 INFO sqlalchemy.engine.Engine [cached since 0.382s ago] (3, 6, 1)
# 2024-12-22 11:38:45,776 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,826 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,826 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:45,827 INFO sqlalchemy.engine.Engine [cached since 0.4557s ago] (4, 7, 2)
# 2024-12-22 11:38:45,852 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,899 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,899 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:45,900 INFO sqlalchemy.engine.Engine [cached since 0.5286s ago] (4, 8, 1)
# 2024-12-22 11:38:45,925 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:45,971 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:45,971 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:45,972 INFO sqlalchemy.engine.Engine [cached since 0.6006s ago] (5, 9, 1)
# 2024-12-22 11:38:45,997 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:46,045 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:46,046 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:46,046 INFO sqlalchemy.engine.Engine [cached since 0.6754s ago] (5, 10, 2)
# 2024-12-22 11:38:46,070 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:46,120 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:46,121 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:46,121 INFO sqlalchemy.engine.Engine [cached since 0.7503s ago] (6, 1, 1)
# 2024-12-22 11:38:46,148 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:46,199 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:46,200 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:46,200 INFO sqlalchemy.engine.Engine [cached since 0.8293s ago] (6, 2, 2)
# 2024-12-22 11:38:46,224 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:46,270 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:46,271 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:46,271 INFO sqlalchemy.engine.Engine [cached since 0.9004s ago] (7, 3, 1)
# 2024-12-22 11:38:46,296 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:46,342 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:46,342 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:46,342 INFO sqlalchemy.engine.Engine [cached since 0.9715s ago] (7, 4, 1)
# 2024-12-22 11:38:46,367 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:46,415 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:46,416 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:46,416 INFO sqlalchemy.engine.Engine [cached since 1.045s ago] (8, 5, 2)
# 2024-12-22 11:38:46,441 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:46,488 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:46,489 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:46,489 INFO sqlalchemy.engine.Engine [cached since 1.118s ago] (8, 6, 1)
# 2024-12-22 11:38:46,515 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:46,561 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:46,561 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:46,562 INFO sqlalchemy.engine.Engine [cached since 1.191s ago] (9, 7, 3)
# 2024-12-22 11:38:46,586 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:46,633 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:46,634 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:46,634 INFO sqlalchemy.engine.Engine [cached since 1.263s ago] (9, 8, 1)
# 2024-12-22 11:38:46,656 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:46,703 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:46,704 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:46,705 INFO sqlalchemy.engine.Engine [cached since 1.334s ago] (10, 9, 1)
# 2024-12-22 11:38:46,730 INFO sqlalchemy.engine.Engine COMMIT
# 2024-12-22 11:38:46,781 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-12-22 11:38:46,781 INFO sqlalchemy.engine.Engine INSERT INTO order_items (order_id, product_id, quantity) VALUES (?, ?, ?)
# 2024-12-22 11:38:46,782 INFO sqlalchemy.engine.Engine [cached since 1.411s ago] (10, 10, 1)
# 2024-12-22 11:38:46,806 INFO sqlalchemy.engine.Engine COMMIT
