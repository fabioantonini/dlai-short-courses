# %% [markdown]
# # Pandas for Data Processing
# This notebook contains the commands described in the lecture. Please follow along in this notebook. Feel free to stop the video at any point and explore commands on your own!

# %% [markdown]
# # Lesson 1:
# In this lesson you will:
# - Load a DataFrame from file
# - explore DataFrames
# - view and explore data

# %% [markdown]
# ### Load data from file

# %%
import pandas as pd

# %%
df = pd.read_csv('SalaryDatabase_small.csv')

# %% [markdown]
# ### View data

# %%
df.head(6)

# %%
df.head()

# %%
df.tail()

# %%
df.tail(7)

# %%
df.shape # It's an attribute, not a function, no ()

# %%
df.describe()

# %%
df.info()

# %%
df.columns # It's an attribute, not a function, no ()

# %% [markdown]
# select a subset of columns
# - The inner brackets represent a Python list
# - the outer brackets are pandas notation for accessing the dataframe

# %%
df[ ['Title','Salary'] ]

# %%
df[ ['Title'] ]

# %%
df['Title' ]  # does not return a dataframe.

# %%
df.sample(5)

# %%
df.sample(5, random_state=0)

# %% [markdown]
# # Explore
# Please explore these commands on your own.
# [df.head()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html)
# [df.tail()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html)
# [df.shape](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html)
# [df.describe()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
# [df.info()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html)
# [df.columns](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.columns.html)
# [df.sample()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sample.html)
# [`df[ ['Title','Salary'] ]`](https://pandas.pydata.org/docs/user_guide/indexing.html)
#
# You can also type `df.` and hit `TAB`. Python will show a list of all the possible methods and attributes.
