# %% [markdown]
# # Pandas for Data Processing

# %% [markdown]
# ## GOTO Slides: Course Overview

# %% [markdown]
# # Lesson 1:
#
# ## GOTO Slide: Exploring data
#
# - Load data from file
# - DataFrames
# - view data

# %% [markdown]
# ## GOTO Slide: DataFrame

# %% [markdown]
# ## GOTO Slide: Exploring the DataFrame

# %% [markdown]
# ### Load data from file
#
# Learning Objectives
# - import pandas
# - read_csv()

# %%
import pandas as pd

# %%
df = pd.read_csv('SalaryDatabase_small.csv')

# %% [markdown]
# ### View data
#
# Learning Objectives:
# * df.head(), df.tail(), df.columns(),
# * view subset of rows based on row index
# * df.describe(), df.info(), df.shape
# * select a subset of columns: df['col1','col2']
# * df.sort_values()
# * select subset of rows based on a condition: df.query()

# %%
df.head(6)
# Out:
#                                           Title  \
# 0                     Machine Learning Engineer
# 1  Senior Manager, Machine Learning Engineering
# 2              Senior Machine Learning Engineer
# 3                     Machine Learning Engineer
# 4       Machine Learning Engineer, Data Science
# 5                     Machine Learning Engineer
#
#                                      Location  ds(1)_or_ml  Seniority  Region  \
# 0    San Francisco, California, United States            0          2       1
# 1                     Santa Clara, California            0          4       2
# 2        Sunnyvale, California, United States            0          4       2
# 3        San Diego, California, United States            0          2       4
# 4                   San Francisco, California            0          3       1
# 5  Fountain Valley, California, United States            0          3       3
#
#    Salary
# 0  138483
# 1  172296
# 2  237781
# 3  120817
# 4  165232
# ...

# %%
df.tail(7)
# Out:
#                                 Title                               Location  \
# 13           Associate Data Scientist   Fullerton, California, United States
# 14                     Data Scientist   Sunnyvale, California, United States
# 15  Co-Founder & Chief Data Scientist                      San Francisco, CA
# 16                     Data Scientist                    Fremont, California
# 17                     Data Scientist  Menlo Park, California, United States
# 18         Data Scientist (Tech lead)               Greater Los Angeles Area
# 19                     Data Scientist                               San Jose
#
#     ds(1)_or_ml  Seniority  Region  Salary
# 13            1          2       3  126978
# 14            1          3       2  114917
# 15            1          4       1  210265
# 16            1          3       2  111988
# 17            1          2       2  189417
# 18            1          3       3  136363
# 19            1          3       2  189340

# %%
df.shape # It's an attribute, not a function, no ()

# %%
df.describe()
# Out:
#        ds(1)_or_ml  Seniority     Region         Salary
# count    20.000000  20.000000  20.000000      20.000000
# mean      0.500000   2.700000   1.950000  157859.300000
# std       0.512989   0.732695   0.825578   40521.272503
# min       0.000000   2.000000   1.000000  106294.000000
# 25%       0.000000   2.000000   1.000000  119342.000000
# 50%       0.500000   3.000000   2.000000  158939.000000
# 75%       1.000000   3.000000   2.000000  189359.250000
# max       1.000000   4.000000   4.000000  237781.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        20 non-null     object
#  1   Location     20 non-null     object
#  2   ds(1)_or_ml  20 non-null     int64
#  3   Seniority    20 non-null     int64
#  4   Region       20 non-null     int64
#  5   Salary       20 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 1.1+ KB

# %%
df.columns # It's an attribute, not a function, no ()
# Out:
# Index(['Title', 'Location', 'ds(1)_or_ml', 'Seniority', 'Region', 'Salary'], dtype='object')

# %% [markdown]
# select a subset of columns
# - The inner brackets represent a Python list
# - the outer brackets are pandas notation for accessing the dataframe

# %%
df[ ['Title','Salary'] ]
# Out:
#     Salary
# 0   138483
# 1   172296
# 2   237781
# 3   120817
# 4   165232
# 5   152646
# 6   210640
# 7   179940
# 8   172080
# 9   106294
# 10  110393
# 11  109409
# 12  201907
# 13  126978
# 14  114917
# 15  210265
# 16  111988
# 17  189417
# 18  136363
# 19  189340

# %%
df.sample(5, random_state=0)
# Out:
#                                                 Title  \
# 18                         Data Scientist (Tech lead)
# 1        Senior Manager, Machine Learning Engineering
# 19                                     Data Scientist
# 8           Senior Machine Learning Research Engineer
# 10  Senior Data Scientist/Machine Learning Researcher
#
#                      Location  ds(1)_or_ml  Seniority  Region  Salary
# 18   Greater Los Angeles Area            1          3       3  136363
# 1     Santa Clara, California            0          4       2  172296
# 19                   San Jose            1          3       2  189340
# 8   Mountain View, California            0          2       2  172080
# 10          San Francisco, CA            1          2       1  110393

# %% [markdown]
# ## GOTO Slide: Selecting columns
